# %% [markdown]
# # Pyplot
# ### pengertian : koleksi atau kumpulan fungsi yang menjadikan matplotlib dan memiliki kerja seperti matlab

# %%
# import module
import matplotlib
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# # Sederhana

# %%
plt.plot([1,4,2,9])
plt.ylabel('Sumbh y ')
plt.show()

# %%
plt.plot([1,2,3,4,5,4])
plt.show()
