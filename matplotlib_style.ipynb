# %% [markdown]
# # Matplotlib style

# %%
import matplotlib
import matplotlib.pyplot as plt 
from matplotlib import style
import numpy as np

# %% [markdown]
# ## Fungsi Plotting

# %%
def gambar_barplot():
    data1 = [25, 85, 75, 40, 60]
    data2 = [40,35,20,55,10]
    kategori = ['A', 'B', 'C', 'D', 'E']

    x = np.arange(len(kategori))

    width = 0.35

    plt.bar(x-width/2, data1, width, label='Data 1') 
    plt.bar(x+width/2, data2, width, label='Data 2') 
    # berasosiasi dengan nilai x dari(len(kategori)) sekaligus mengatur width nya agar tidak tumpuk jadi ada +(data2) dan -(data1) atau data1(kiri) data2(kanan) 

    plt.xticks(x, kategori) # digunakan untuk mengatur menginisiasi labelnya(penampung index, diubah ke dalam kategori) 


    plt.grid(linestyle='--', # mengubah menjadi garis2
            linewidth=1, # mengatur ketebalan
            axis = 'y', # pilihan x, y, both
            alpha= 0.75 # transparansi
            )

    plt.xlabel('kategori')
    plt.ylabel('jumlah')
    plt.title(' Contoh Grouped Bar Plot ')

    plt.legend()
    plt.show()

# %%
gambar_barplot()

# %% [markdown]
# # Mengenal Matplotlib Style

# %%
# daftar style matplotlib
plt.style.available # untuk mengetahui apa saja method nya
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# cara merubahan style dari matplotlib
style.use('ggplot') # style.use('nama style yang digunakan')
gambar_barplot()

# %%
style.use('seaborn')
gambar_barplot()
# Out:
# C:\Users\davar\AppData\Local\Temp\ipykernel_2536\1023044183.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   style.use('seaborn')

# %%
style.use('seaborn-paper')
gambar_barplot()
# Out:
# C:\Users\davar\AppData\Local\Temp\ipykernel_2536\659532134.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   style.use('seaborn-paper')

# %%
style.use('grayscale')
gambar_barplot()
